# %% [markdown]
# ## DICTIONARIES WORKSHEET SOLUTION

# %% [markdown]
# ### MULTIPLE CHOICE QUESTIONS

# %% [markdown]
# ```python
#
# i) c) Unordered data
# ii) b) key-value pair
# iii) a) key
# iv) a) Mutable dictionary
# v) c) [4,5]
# vi) b) {3:10, 4:15}
# vii) d) [3,5]
# viii) b) A value
#
# ```

# %% [markdown]
# ### FILL IN THE BLANKS
#
# ```python
# i) mutable
# ii) value
# iii) keys()
# iv) Traversing a dictionary
# v) pop
# vi) nested dictionary
# vii) boolean
# viii) clear()
# ```

# %% [markdown]
# ### CASE STUDY QUESTIONS
#
# ```python
# 4.(i)
#
# (i) 4. 0
# (ii) 2. In the form of a list (but as key-value pairs)
# (iii) 2. Key-value pairs as the elements pf a list
# (iv) 3. Any key-value pair randomly
#
#
# (ii)
# for x in employee:
#     if employee[x]['Age'] >= 55:
#         incr = employee[x]["Salary"]*0.2
#         employee[x]['Salary'] = employee[x]['Salary'] + incr
# print(employee)
#
# (i) employee
# (ii) 'Age'
# (iii) 0.2
# (iv) employee[x]['Salary']
#
# 5.
# (i)
# 10
# 30
# 60
# 100
#
# (ii)
# 12
# 3
#
# (iii)
# 4
#
# (iv)
# None
# [1, 2, 3, 4, 4, 5, 6]
# [1, 2, 3, 4, 1, 2, 3, 4]
# {1: [1, 2, 3, 4], 2: [4, 5, 6], 3: [7, 8, 9]}
#
# (v)
# {'a': 12, 'e': 18, 'i': 20, 'o': 15, 'u': 25}
#
# (vi)
# dict_keys(['a', 'b', 'c'])
# dict_values([[1, 2, 3], (1, 2, 3), 'Python'])
#
# (vii) False
#
# (viii) 4
#
# (ix)
# {1: 10, 2: 10, 3: 8, 4: 6, 5: 12}
#
# (x)
# {'Aman': 80, 'Sumit': 30, 'Dinesh': 30, 'Suresh': 20}
#
# (xi)
# dict_keys([5, 'a'])
# dict_values([[6, 7, 8], (1, 2, 3)])
#
# (xii)
# Dictionary contents:
# 5 : number numbernumbernumber
#
# a : string stringstringstring
#
# (1, 2) : tuple tupletupletuple
#
# (xiii)
# {left} and {right} or {right} and {left}
#
# (xiv)
# >
# >
#
# end
#
# (xv)
# my_dict = {}
# my_dict [(1,2,4)] = 8
# my_dict [[4,2,1]] = 10  # ERROR LIST
# my_dict [(4,2,1)] = 10
# print (my_dict)
#
# {(1, 2, 4): 8, (4, 2, 1): 10}
# ```
